# %% [markdown]
# # Este cuaderno busca el mejor modelo para cada horizonte temporal, estadío base y variable de salida

# %%
## Librerias necesarias
import pycaret
from pycaret.classification import *
from pycaret.classification import ClassificationExperiment

import os
import re
import socket
import shutil
import warnings
import numpy as np
import pandas as pd
import plotly.io as pio
import plotly.express as px 
from sklearn.metrics import confusion_matrix

## Configuración de rutas
if socket.gethostname()=='SRVCBECO01':
    os.chdir(r'C:\Users\juanpablo.martinez\Downloads\ryr_exes')
elif socket.gethostname() == 'HPJP2': 
    os.chdir(r'C:\Users\juanm\Dropbox\JP_files\UR\Vías clinicas diabetes')
elif socket.gethostname() == 'CNF106054': 
    os.chdir(r'C:\Users\paul.rodriguez\Dropbox\Salud Colombia\Diabetes Sanitas\Vías clinicas diabetes')
elif socket.gethostname() == 'CNF77701': 
    os.chdir(r'C:\Users\juanpablo.martinez\Dropbox\Vías clinicas diabetes')

    
raw_path = ''
created_path = ""
temp_path = ''
dbs_path = ""


print('Directorio actual: '+ os.getcwd())
# Out:
# Directorio actual: C:\Users\juanpablo.martinez\Downloads\ryr_exes

# %% [markdown]
# ### Server packages versions

# %%
! pip list
# Out:
# Package                            Version
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lick (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lick (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lick (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ltk (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lick (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# ---------------------------------- --------------------
# absl-py                            1.2.0
# alabaster                          0.7.12
# alembic                            1.11.2
# anaconda-client                    1.9.0
# anaconda-navigator                 2.1.2
# anaconda-project                   0.10.1
# ansi2html                          1.8.0
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.7
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.10.0
# binaryornot                        0.4.4
# bitarray                           2.3.0
# bkcharts                           0.2
# black                              19.10b0
# bleach                             4.0.0
# blis                               0.7.7
# bokeh                              2.4.1
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cached-property                    1.5.2
# cachetools                         5.2.0
# catalogue                          2.0.7
# category-encoders                  2.5.0
# certifi                            2021.10.8
# certipy                            0.1.3
# cffi                               1.14.6
# chardet                            4.0.0
# charset-normalizer                 2.0.4
# click                              7.1.2
# cloudpickle                        2.0.0
# clyent                             1.2.2
# colorama                           0.4.4
# colorcet                           3.0.1
# comtypes                           1.1.10
# conda                              4.11.0
# conda-build                        3.21.6
# conda-content-trust                0+unknown
# conda-pack                         0.6.0
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cookiecutter                       1.7.2
# cryptography                       3.4.8
# cycler                             0.10.0
# cymem                              2.0.6
# Cython                             0.29.24
# cytoolz                            0.11.0
# daal4py                            2021.3.0
# dash                               2.11.1
# dash-core-components               2.0.0
# dash-html-components               2.0.0
# dash-table                         5.0.0
# dask                               2021.10.0
# databricks-cli                     0.17.7
# debugpy                            1.4.1
# decorator                          4.4.2
# defusedxml                         0.7.1
# Deprecated                         1.2.14
# deprecation                        2.1.0
# diff-match-patch                   20200713
# distributed                        2021.10.0
# docker                             6.1.3
# docutils                           0.17.1
# emoji                              1.7.0
# en-core-web-sm                     3.2.0
# entrypoints                        0.3
# es-core-news-sm                    3.3.0
# et-xmlfile                         1.1.0
# exceptiongroup                     1.1.0
# fastcache                          1.1.0
# fastjsonschema                     2.18.0
# filelock                           3.3.1
# flake8                             3.9.2
# Flask                              1.1.2
# flatbuffers                        22.9.24
# fonttools                          4.25.0
# fsspec                             2021.10.1
# future                             0.18.2
# gast                               0.4.0
# gevent                             21.8.0
# gitdb                              4.0.10
# GitPython                          3.1.32
# glob2                              0.7
# google-auth                        2.12.0
# google-auth-oauthlib               0.4.6
# google-pasta                       0.2.0
# googletrans                        2.4.0
# greenlet                           1.1.1
# grpcio                             1.49.1
# h11                                0.14.0
# h5py                               3.2.1
# HeapDict                           1.0.1
# holoviews                          1.15.1
# html5lib                           1.1
# huggingface-hub                    0.6.0
# idna                               3.2
# imagecodecs                        2021.8.26
# imageio                            2.9.0
# imagesize                          1.2.0
# imbalanced-learn                   0.9.1
# imblearn                           0.0
# importlib-metadata                 6.8.0
# inflection                         0.5.1
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          6.4.1
# ipython                            7.29.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.5
# isort                              5.9.3
# itsdangerous                       2.0.1
# jdcal                              1.4.1
# jedi                               0.18.0
# jellyfish                          0.8.2
# Jinja2                             3.1.2
# jinja2-time                        0.2.0
# joblib                             1.3.2
# json5                              0.9.6
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.8.1
# jupyter-server                     1.4.1
# jupyter-telemetry                  0.1.0
# jupyterhub                         4.0.2
# jupyterlab                         3.2.1
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.8.2
# jupyterlab-widgets                 1.0.0
# kaleido                            0.2.1
# keras                              2.10.0
# Keras-Preprocessing                1.1.2
# keyring                            23.1.0
# kiwisolver                         1.3.1
# kmodes                             0.12.1
# langcodes                          3.3.0
# langid                             1.1.6
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# libclang                           14.0.6
# lightgbm                           4.0.0
# llvmlite                           0.40.1
# locket                             0.2.1
# lxml                               4.6.3
# Mako                               1.2.4
# Markdown                           3.4.1
# MarkupSafe                         2.1.3
# matplotlib                         3.4.3
# matplotlib-inline                  0.1.2
# mca                                1.0.3
# mccabe                             0.6.1
# menuinst                           1.4.18
# mglearn                            0.1.9
# mistune                            3.0.1
# mkl-fft                            1.3.1
# mkl-random                         1.2.2
# mkl-service                        2.4.0
# mlflow                             2.5.0
# mock                               4.0.3
# more-itertools                     8.10.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# munkres                            1.1.4
# murmurhash                         1.0.6
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          7.7.3
# nbformat                           5.9.2
# nest-asyncio                       1.5.1
# networkx                           2.5.1
# nltk                               3.6.2
# nose                               1.3.7
# notebook                           6.4.5
# numba                              0.57.1
# numexpr                            2.7.3
# numpy                              1.22.4
# numpydoc                           1.1.0
# oauthlib                           3.2.1
# olefile                            0.46
# opencv-python                      4.6.0.66
# openpyxl                           3.0.9
# opt-einsum                         3.3.0
# orjson                             3.9.4
# outcome                            1.2.0
# packaging                          21.3
# pandas                             1.3.4
# pandocfilters                      1.4.3
# panel                              0.14.0
# param                              1.12.2
# paramiko                           2.7.2
# parso                              0.8.2
# partd                              1.2.0
# path                               16.0.0
# pathlib2                           2.3.6
# pathspec                           0.7.0
# pathy                              0.6.1
# patsy                              0.5.2
# pdf2image                          1.16.0
# pdfminer3k                         1.3.4
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.4.0
# pip                                21.2.4
# pkginfo                            1.7.1
# plotly                             5.10.0
# plotly-resampler                   0.9.1
# pluggy                             0.13.1
# ply                                3.11
# pmdarima                           2.0.3
# poyo                               0.5.0
# preshed                            3.0.6
# prince                             0.7.1
# prometheus-client                  0.11.0
# prompt-toolkit                     3.0.20
# protobuf                           3.19.6
# psutil                             5.9.5
# psycopg2                           2.9.5
# ptyprocess                         0.7.0

# %% [markdown]
# ## Funciones

# %% [markdown]
# ### Definición de parámetros básicos

# %%
def parameters_gather(tgt_year, base_label, dep_var):
    
    ## Construyendo los paths de entrenamiento y validación
    train_path = dbs_path+"train\\train_db_{}_years_base_{}.csv".format(tgt_year, base_label)
    vali_path = dbs_path+"vali\\vali_db_{}_years_base_{}.csv".format(tgt_year, base_label)

    ## Listado de variables a eliminar 
    vars_to_drop = ['KeyAnonimo', 'year', 'base_label', 'tgt_label']
    if dep_var == "comorbilidades":
        vars_to_drop = vars_to_drop+['fuera_metas']
    elif dep_var == "fuera_metas":
        vars_to_drop = vars_to_drop+['comorbilidades']
    
    return train_path, vali_path, vars_to_drop
# Out:
# py                                 1.10.0
# pyarrow                            12.0.1
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pybind11                           2.6.1
# pycaret                            3.0.4
# pycodestyle                        2.7.0
# pycosat                            0.6.3
# pycparser                          2.20
# pyct                               0.4.8
# pycurl                             7.44.1
# pydantic                           1.8.2
# pydocstyle                         6.1.1
# pyerfa                             2.0.0
# pyflakes                           2.3.1
# Pygments                           2.10.0
# PyGreSQL                           5.2.4
# PyJWT                              2.1.0
# pylint                             2.9.6
# pyls-spyder                        0.4.0
# PyNaCl                             1.4.0
# pyod                               1.1.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          21.0.0
# pyparsing                          3.0.4
# PyPDF2                             1.26.0
# pyreadline                         2.1
# pyrsistent                         0.18.0
# pySankey                           0.0.1
# pysbd                              0.3.4
# PySocks                            1.7.1
# pyspellchecker                     0.6.2
# pytesseract                        0.3.9
# pytest                             6.2.4
# python-dateutil                    2.8.2
# python-docx                        0.8.11
# python-json-logger                 2.0.7
# python-lsp-black                   1.0.0
# python-lsp-jsonrpc                 1.0.0
# python-lsp-server                  1.2.4
# python-slugify                     5.0.2
# pytz                               2021.3
# pyviz-comms                        2.2.1
# PyWavelets                         1.1.1
# pywin32                            306
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             6.0
# pyzmq                              22.2.1
# QDarkStyle                         3.0.2
# qstylizer                          0.1.10
# QtAwesome                          1.0.2
# qtconsole                          5.1.1
# QtPy                               1.10.0
# querystring-parser                 1.2.4
# regex                              2021.8.3
# reportlab                          3.5.68
# requests                           2.31.0
# requests-oauthlib                  1.3.1
# retrying                           1.3.4
# rope                               0.19.0
# rsa                                4.9
# Rtree                              0.9.7
# ruamel.yaml                        0.17.32
# ruamel.yaml.clib                   0.2.7
# ruamel-yaml-conda                  0.15.100
# schemdraw                          0.15
# scikit-base                        0.5.0
# scikit-image                       0.18.3
# scikit-learn                       1.1.3
# scikit-learn-intelex               2021.20210714.120553
# scikit-plot                        0.3.7
# scipy                              1.7.1
# seaborn                            0.11.2
# selenium                           4.8.0
# Send2Trash                         1.8.0
# setuptools                         58.0.4
# shap                               0.42.1
# simplegeneric                      0.8.1
# singledispatch                     3.7.0
# sip                                4.19.13
# six                                1.16.0
# sktime                             0.21.0
# slate3k                            0.5.3
# slicer                             0.0.7
# smart-open                         5.2.1
# smmap                              5.0.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.2.1
# spacy                              3.2.4
# spacy-legacy                       3.0.9
# spacy-loggers                      1.0.2
# Sphinx                             4.2.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             5.1.5
# spyder-kernels                     2.1.3
# SQLAlchemy                         1.4.22
# sqlparse                           0.4.4
# srsly                              2.4.3
# stanza                             1.4.0
# statsmodels                        0.14.0
# sympy                              1.9
# tables                             3.6.1
# tabulate                           0.9.0
# tbats                              1.1.3
# TBB                                0.2
# tblib                              1.7.0
# tenacity                           8.1.0
# tensorboard                        2.10.1
# tensorboard-data-server            0.6.1
# tensorboard-plugin-wit             1.8.1
# tensorflow                         2.10.0
# tensorflow-estimator               2.10.0
# tensorflow-io-gcs-filesystem       0.27.0
# termcolor                          2.0.1
# terminado                          0.9.4
# testpath                           0.5.0
# text-unidecode                     1.3
# textdistance                       4.2.1
# thinc                              8.0.15
# threadpoolctl                      2.2.0
# three-merge                        0.1.1
# tifffile                           2021.7.2
# tinycss                            0.4
# tinycss2                           1.2.1
# tokenizers                         0.12.1
# toml                               0.10.2
# toolz                              0.11.1
# torch                              1.11.0
# tornado                            6.1
# tqdm                               4.62.3
# trace-updater                      0.0.9.1
# traitlets                          5.1.0
# transformers                       4.19.0
# trio                               0.22.0
# trio-websocket                     0.9.2
# tsdownsample                       0.1.2
# typed-ast                          1.4.3
# typer                              0.4.1
# typing_extensions                  4.7.1
# ujson                              4.0.2
# unicodecsv                         0.14.1
# Unidecode                          1.2.0
# urllib3                            1.26.7
# waitress                           2.1.2
# wasabi                             0.9.1
# watchdog                           2.1.3
# wcwidth                            0.2.5
# webencodings                       0.5.1
# websocket-client                   1.6.1
# Werkzeug                           2.0.2
# wheel                              0.37.0
# whichcraft                         0.6.1
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wordcloud                          1.8.2.2
# wrapt                              1.12.1
# wsproto                            1.2.0
# xlrd                               2.0.1
# XlsxWriter                         3.0.1
# xlwings                            0.24.9
# xlwt                               1.3.0
# xmltodict                          0.12.0
# xxhash                             3.3.0
# yapf                               0.31.0
# yellowbrick                        1.5
# zict                               2.0.0
# zipp                               3.6.0
# zope.event                         4.5.0
# zope.interface                     5.4.0

# %% [markdown]
# ### Preparación de las bases de entrenamiento y validación

# %%
def data_prepare(df_path, vars_to_drop):
    ## Cargando la base de datos
    data_mat = pd.read_csv(df_path)
    
    ## Eliminando variables innecesarias
    data_mat.drop(vars_to_drop, axis = 1, inplace = True)
    
    return(data_mat.reset_index(drop = True))

# %% [markdown]
# ### Identifcando variables categóricas y numéricas en la base de datos

# %%
def cat_num_identify(ml_data, rename_df):
    categorical_vars_master = ['femenino', 'ERC_high', 'ERC1', 'ERC2', 'adhiere_guia', 'no_adhiere', 'adhiere_colesterol', 'analgesicos',
                                   'antiacidos', 'antihipertensivos', 'hipoglicemiantes', 'hipolipemiantes', 'nutrition_tag_max', 
                                   'exercise_tag_max', 'alcohol_tag_max', 'tobaco_tag_max', 'creatinina_missing']

    categorical_vars = list(set(ml_data.columns).intersection(categorical_vars_master))

    numerical_vars = set(ml_data.columns).difference(set(categorical_vars+['KeyAnonimo', 'year', 'base_label', 'comorbilidades', 'fuera_metas', 'tgt_label']))
    numerical_vars = list(numerical_vars)

    types_df = pd.DataFrame({'old_name' : categorical_vars+numerical_vars,
                             'type' : ['categorical']*len(categorical_vars)+['numerical']*len(numerical_vars)})

    types_df = types_df.merge(rename_df, on = 'old_name', how = 'inner')

    new_cat_vars = list(types_df.loc[types_df['type'] == 'categorical', 'new_name'].values)
    new_num_vars = list(types_df.loc[types_df['type'] == 'numerical', 'new_name'].values)
    
    return new_cat_vars, new_num_vars

# %% [markdown]
# ## Parámetros básicos

# %%
## Diccionario para renombrar variables
rename_dict ={'femenino' : 'Female', 'edad' : 'Age (Years)', 'peso': 'Weight (Kg)', 'talla' : 'Height (m)', 
              'imc' : "BMI (kg/m*m)", 'Colesterol_LDL' : 'LDL Chol. (mg/dL)', 'TFG' : "eGFR (mg/g)", 
              "ta_diastolica" : "Diast. B.P. (mmHg)", 'ta_sistolica' : 'Sist. B.P. (mmHg)', 'adhiere_guia' : "Hba1c guide Adh.", 
              "no_adhiere" : "Pharma. Adh.", "analgesicos" : "Analgesics", "antiacidos" : "Antacids",
              "antihipertensivos" : "Antihypertensive", "hipoglicemiantes" : "Hypoglecimic agents", 
              "hipolipemiantes" : "Lipid-lowering agents", "nutrition_tag_max" : "Nutrition recomm.", 
              "exercise_tag_max" : "Physical act. recomm.", "alcohol_tag_max" : "Alcohol recomm.",
              "tobaco_tag_max" : "Tobacco recomm.", "creatinina" : "Creatinine (mg/dL)", 
              "adhiere_colesterol" : "Chol. Adh.", 
             "ERC1" : "CKD-1", "ERC2" : "CKD-2", "ERC3" : "CKD-Late"} 

#'imc': r"BMI ($\displaystyle\frac{kg}{m^2}$)"}

rename_df = pd.DataFrame(rename_dict, index = rename_dict.keys())
rename_df = pd.DataFrame({'old_name' : rename_df.index, 'new_name' : np.diag(rename_df)})

# %% [raw]
# ## Comparando los modelos

# %% [raw]
# ### Cargando la info. de Pycaret

# %% [raw]
# ## Load all the .csv files
# all_results = []
# for file_name in [each for each in os.listdir(temp_path+"ryr_results/baseline_replicate/") if each.endswith('.csv')]:
#     all_results.append(pd.read_csv(temp_path+"ryr_results/baseline_replicate/"+file_name, sep = ';'))
#
# ## Append all the results
# all_results = pd.concat(all_results).reset_index(drop = True)
#
# appendix_table = all_results[all_results['samp_type'] != "train_manual"]
#
# # Isolating the best models in terms of F1
# cols_order = ['tgt_year', 'base_label', 'dep_var', 'samp_type']+['Model', "Accuracy", "AUC", "F1", "Kappa"]
# best_models_index = all_results.loc[all_results['samp_type'] == "training",
#                                     ['tgt_year',
#                                      'base_label',
#                                      'dep_var',
#                                      'F1']].groupby(['tgt_year',
#                                                      'base_label',
#                                                      'dep_var']).idxmax().reset_index(drop = True)["F1"]
#
# ## Keep the validation result and the best training result
# ordered_results = pd.concat([all_results.loc[best_models_index, cols_order],
#            all_results.loc[all_results['samp_type'] == "validation", cols_order]])

# %% [raw]
# ### Cargando la info. de las  redes neuronales y otros modelos específico

# %% [raw]
# ## Gathering the info. from the Neural Networks
# dep_var = "fuera_metas"
#
# # Iterate across years and initial statess
# for tgt_year in [1, 2]:
#     for base_label in [1, 3]:
#         # Load the Neural Networks results
#         nn_models = pd.read_csv(temp_path+'nn_res_{}_{}_years_base_{}.csv'.format(dep_var, tgt_year, base_label))
#         nn_models['Model'] = "NN"
#
#         # Iterate across possible samples
#         for tgt_samp in ["training", "validation"]:
#
#             best_model = nn_models.loc[(nn_models['samp_type'] == tgt_samp), 'f1'].idxmax()
#
#             # Manually replace the Model type, accuracy, AUC and F1 score
#             index_to_replace = (ordered_results['dep_var'] == dep_var) & (ordered_results['tgt_year'] == tgt_year) & (ordered_results['base_label'] == base_label) & (ordered_results['samp_type'] == tgt_samp)
#             ordered_results.loc[index_to_replace, "Model"] = "NN"
#             ordered_results.loc[index_to_replace, "Accuracy"] = nn_models.loc[best_model, "accuracy"]
#             ordered_results.loc[index_to_replace, "AUC"] = nn_models.loc[best_model, "auc"]
#             ordered_results.loc[index_to_replace, "F1"] = nn_models.loc[best_model, "f1"]
#
# dep_var = "fuera_metas"
# tgt_year = 2
# base_label = 2
# tgt_model = "Light Gradient Boosting Machine"
# for tgt_samp in ["training", "validation"]:
#
#     # Manually replace the Model type, accuracy, AUC and F1 score
#     best_model = pd.read_csv(temp_path+"org_{}_years_base_{}_{}.csv".format(tgt_year, base_label, dep_var), sep = ';')
#     best_model = best_model[(best_model['samp_type'] == tgt_samp) & (best_model['Model'] == tgt_model)].reset_index(drop = True)
#
#     index_to_replace = (ordered_results['dep_var'] == dep_var) & (ordered_results['tgt_year'] == tgt_year) & (ordered_results['base_label'] == base_label) & (ordered_results['samp_type'] == tgt_samp)
#     ordered_results.loc[index_to_replace, "Model"] = best_model.loc[0, "Model"]
#     ordered_results.loc[index_to_replace, "Accuracy"] = best_model.loc[0, "Accuracy"]
#     ordered_results.loc[index_to_replace, "AUC"] = best_model.loc[0, "AUC"]
#     ordered_results.loc[index_to_replace, "F1"] = best_model.loc[0, "F1"]

# %% [raw]
# dep_var = "fuera_metas"
# tgt_year = 2
# base_label = 4
# tgt_model = "Logistic Regression"
#
# for tgt_samp in ["training", "validation"]:
#
#     # Manually replace the Model type, accuracy, AUC and F1 score
#     best_model = pd.read_csv(temp_path+"org_{}_years_base_{}_{}.csv".format(tgt_year, base_label, dep_var), sep = ';')
#     best_model = best_model[(best_model['samp_type'] == tgt_samp) & (best_model['Model'] == tgt_model)].reset_index(drop = True)
#
#     index_to_replace = (ordered_results['dep_var'] == dep_var) & (ordered_results['tgt_year'] == tgt_year) & (ordered_results['base_label'] == base_label) & (ordered_results['samp_type'] == tgt_samp)
#     ordered_results.loc[index_to_replace, "Model"] = best_model.loc[0, "Model"]
#     ordered_results.loc[index_to_replace, "Accuracy"] = best_model.loc[0, "Accuracy"]
#     ordered_results.loc[index_to_replace, "AUC"] = best_model.loc[0, "AUC"]
#     ordered_results.loc[index_to_replace, "F1"] = best_model.loc[0, "F1"]

# %% [raw]
# ### Editando las entradas como en el paper

# %% [raw]
# # Change the variables' labels
# ordered_results["tgt_year"].replace(to_replace = [1, 2],
#                                       value = ["1-year",
#                                                "2-year"],
#                                         inplace = True)
#
# ordered_results["base_label"].replace(to_replace = [1, 2, 3, 4],
#                                       value = ["1 On-target",
#                                                  "2 Out-target",
#                                                  "3 Not-complications",
#                                                  "4 Yes-complications"],
#                                         inplace = True)
#
# ordered_results["dep_var"].replace(to_replace = ["fuera_metas", "comorbilidades"],
#                                       value = ["Out-target", "Yes-complications"],
#                                         inplace = True)
#
# ordered_results["samp_type"].replace(to_replace = ["training", "validation"],
#                                       value = ["Training", "Validation"],
#                                         inplace = True)
#
# ordered_results['Model'].replace(to_replace = ["Logistic Regression",
#                                                "Ada Boost Classifier",
#                                                "Gradient Boosting Machine",
#                                                "Gradient Boosting Classifier"],
#                                  value = ["LR", "AdaBoost", "LGBoost", "GBC"],
#                                 inplace = True)
#
# ## Export the long version of the picked models for comparisons
# ordered_results.to_csv(temp_path + 'original_submission_res_long.csv',
#                        sep = ';', index = False)
#
# # From long to wide table
# reshaped_results = pd.pivot(ordered_results,
#                             index = ['tgt_year', 'base_label', 'dep_var', 'Model'],
#                             columns = "samp_type",
#                             values = [#'Model',
#                                       'Accuracy',
#                                       'F1',
#                                       'AUC']).reset_index()
#
# # Renaming different columns
# rename_dict = {"tgt_year" : "Horizon",
#                "base_label" : "Initial condition",
#                "dep_var" : "Prediction"}
#
# # Custom sorting of the table
# paper_table = pd.concat([reshaped_results[(reshaped_results['dep_var'] == "Out-target") & (reshaped_results['tgt_year'] == "1-year")],
#                          reshaped_results[(reshaped_results['dep_var'] == "Yes-complications") & (reshaped_results['tgt_year'] == "1-year")],
#                          reshaped_results[(reshaped_results['dep_var'] == "Out-target") & (reshaped_results['tgt_year'] == "2-year")],
#                          reshaped_results[(reshaped_results['dep_var'] == "Yes-complications") & (reshaped_results['tgt_year'] == "2-year")]]
#                        ).rename(rename_dict, axis = 1)
#
# # Final cleaning
# paper_table['Initial condition'] = paper_table['Initial condition'].str.replace('\d+', '')

# %% [raw]
# ## Export the table in .csv format
# paper_table.loc[:, [('Horizon',''),
#                     ('Initial condition',''),
#                     ('Prediction',''),
#                     ('Model',''),
#                     ("Accuracy", "Training"),
#                     ("F1", "Training"),
#                     ("AUC", "Training"),
#                     ("Accuracy", "Validation"),
#                     ("F1", "Validation"),
#                     ("AUC", "Validation")]]

# %% [raw]
# ## Export the table in .csv format
# paper_table.loc[:, [('Horizon',''),
#                     ('Initial condition',''),
#                     ('Prediction',''),
#                     ('Model',''),
#                     ("Accuracy", "Training"),
#                     ("F1", "Training"),
#                     ("AUC", "Training"),
#                     ("Accuracy", "Validation"),
#                     ("F1", "Validation"),
#                     ("AUC", "Validation")]].to_csv(temp_path+'original_submission_res.csv',
#                                                    sep = ';',
#                                                    index = False)

# %% [raw]
# ## Generating the appendix table
#
# # Change the variables' labels
# appendix_table["tgt_year"].replace(to_replace = [1, 2],
#                                       value = ["1-year",
#                                                "2-year"],
#                                         inplace = True)
#
# appendix_table["base_label"].replace(to_replace = [1, 2, 3, 4],
#                                       value = ["On-target",
#                                                  "Out-target",
#                                                  "Not-complicatons",
#                                                  "Yes-complications"],
#                                         inplace = True)
#
# appendix_table["dep_var"].replace(to_replace = ["fuera_metas", "comorbilidades"],
#                                       value = ["Out-target", "Yes-complications"],
#                                         inplace = True)
#
# appendix_table["samp_type"].replace(to_replace = ["training", "validation"],
#                                       value = ["Training", "Validation"],
#                                         inplace = True)
#
# # Renaming different columns
# rename_dict = {"tgt_year" : "Horizon",
#                "base_label" : "Initial condition",
#                "dep_var" : "Prediction",
#                "samp_type" : "Sample type"}
# appendix_table = appendix_table.loc[:, cols_order].rename(rename_dict, axis = 1)
#
# appendix_table.to_csv(temp_path+"all_trained_models_metrics.csv", sep = ';', index = False)

# %% [markdown]
# ## Generating the requested plots and tables - Reviewer 4

# %% [markdown]
# ### Feature importance of two models

# %%
dep_var = "fuera_metas"
tgt_year = 1
base_label = 2

print("Training horizon: {}, Initial state: {}, Outcome: {}.".format(tgt_year, base_label, dep_var))

# Generando las rutas y variables a eliminar
train_path, vali_path, vars_to_drop = parameters_gather(tgt_year = tgt_year, 
                                                        base_label = base_label,
                                                        dep_var = dep_var)

## Preparando los datos
train = data_prepare(df_path = train_path, vars_to_drop = vars_to_drop)
#train = pd.read_csv(train_path)
#train = train.loc[:, list(set(train.columns).difference(set(vars_to_drop)))]
vali = data_prepare(df_path = vali_path, vars_to_drop = vars_to_drop)

## Identificando variables categóricas y numéricas presentes
cat_vars, num_vars = cat_num_identify(ml_data = train, rename_df = rename_df)

## Renombrando las variables para el gráfico
train.rename(rename_dict, axis = 1, inplace = True)
vali.rename(rename_dict, axis = 1, inplace = True)

## Configuración del experimento
s = setup(data = train,
          target = dep_var,
          test_data = vali,
          session_id = 123,
          index = False,
          numeric_features = num_vars,
          categorical_features = cat_vars,
          remove_multicollinearity = True,
          fix_imbalance = False,
          feature_selection = True,
          #feature_selection = False,
          feature_selection_method = "sequential",
          n_features_to_select = 0.5,
          use_gpu = False, 
         # log_experiment = True
         )

# compare baseline models
best = compare_models(sort = "F1", include = ['lr'])

# Generate feature importance plot 
plot_model(best, plot = 'feature', save = True)
shutil.copyfile(".\\"+"Feature Importance.png",
                ".\\"+temp_path+"ryr_results\\baseline_replicate\\predicted_probabilities\\features_{}_years_base_{}_{}.png".format(tgt_year, base_label, dep_var))
os.remove(".\\"+"Feature Importance.png")
# Out:
# Training horizon: 1, Initial state: 2, Outcome: fuera_metas.
# <style type="text/css">
# #T_f7cc8_row10_col1, #T_f7cc8_row16_col1, #T_f7cc8_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f7cc8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7cc8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7cc8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f7cc8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f7cc8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f7cc8_row1_col1" class="data row1 col1" >fuera_metas</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f7cc8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f7cc8_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f7cc8_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f7cc8_row3_col1" class="data row3 col1" >(4081, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f7cc8_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f7cc8_row4_col1" class="data row4 col1" >(4081, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f7cc8_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f7cc8_row5_col1" class="data row5 col1" >(2856, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f7cc8_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f7cc8_row6_col1" class="data row6 col1" >(1225, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f7cc8_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_f7cc8_row7_col1" class="data row7 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f7cc8_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_f7cc8_row8_col1" class="data row8 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f7cc8_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_f7cc8_row9_col1" class="data row9 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f7cc8_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_f7cc8_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f7cc8_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_f7cc8_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f7cc8_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_f7cc8_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f7cc8_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_f7cc8_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f7cc8_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_f7cc8_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f7cc8_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_f7cc8_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f7cc8_row16_col0" class="data row16 col0" >Remove multicollinearity</td>
#       <td id="T_f7cc8_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f7cc8_row17_col0" class="data row17 col0" >Multicollinearity threshold</td>
#       <td id="T_f7cc8_row17_col1" class="data row17 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f7cc8_row18_col0" class="data row18 col0" >Feature selection</td>
#       <td id="T_f7cc8_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f7cc8_row19_col0" class="data row19 col0" >Feature selection method</td>
#       <td id="T_f7cc8_row19_col1" class="data row19 col1" >sequential</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f7cc8_row20_col0" class="data row20 col0" >Feature selection estimator</td>
#       <td id="T_f7cc8_row20_col1" class="data row20 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f7cc8_row21_col0" class="data row21 col0" >Number of features selected</td>
#       <td id="T_f7cc8_row21_col1" class="data row21 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f7cc8_row22_col0" class="data row22 col0" >Fold Generator</td>
#       <td id="T_f7cc8_row22_col1" class="data row22 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f7cc8_row23_col0" class="data row23 col0" >Fold Number</td>
#       <td id="T_f7cc8_row23_col1" class="data row23 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_f7cc8_row24_col0" class="data row24 col0" >CPU Jobs</td>
#       <td id="T_f7cc8_row24_col1" class="data row24 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_f7cc8_row25_col0" class="data row25 col0" >Use GPU</td>
#       <td id="T_f7cc8_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_f7cc8_row26_col0" class="data row26 col0" >Log Experiment</td>
#       <td id="T_f7cc8_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_f7cc8_row27_col0" class="data row27 col0" >Experiment Name</td>
#       <td id="T_f7cc8_row27_col1" class="data row27 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f7cc8_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_f7cc8_row28_col0" class="data row28 col0" >USI</td>
#       <td id="T_f7cc8_row28_col1" class="data row28 col1" >9968</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_694c5_ th {
#   text-align: left;
# }
# #T_694c5_row0_col0 {
#   text-align: left;
# }
# #T_694c5_row0_col1, #T_694c5_row0_col2, #T_694c5_row0_col3, #T_694c5_row0_col4, #T_694c5_row0_col5, #T_694c5_row0_col6, #T_694c5_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_694c5_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_694c5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_694c5_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_694c5_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_694c5_row0_col1" class="data row0 col1" >0.7223</td>
#       <td id="T_694c5_row0_col2" class="data row0 col2" >0.5145</td>
#       <td id="T_694c5_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_694c5_row0_col4" class="data row0 col4" >0.7223</td>
#       <td id="T_694c5_row0_col5" class="data row0 col5" >0.8388</td>
#       <td id="T_694c5_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_694c5_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_694c5_row0_col8" class="data row0 col8" >8.2780</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
dep_var = "fuera_metas"
tgt_year = 1
base_label = 4

print("Training horizon: {}, Initial state: {}, Outcome: {}.".format(tgt_year, base_label, dep_var))

# Generando las rutas y variables a eliminar
train_path, vali_path, vars_to_drop = parameters_gather(tgt_year = tgt_year, 
                                                        base_label = base_label,
                                                        dep_var = dep_var)

## Preparando los datos
train = data_prepare(df_path = train_path, vars_to_drop = vars_to_drop)
#train = pd.read_csv(train_path)
#train = train.loc[:, list(set(train.columns).difference(set(vars_to_drop)))]
vali = data_prepare(df_path = vali_path, vars_to_drop = vars_to_drop)

## Identificando variables categóricas y numéricas presentes
cat_vars, num_vars = cat_num_identify(ml_data = train, rename_df = rename_df)

## Renombrando las variables para el gráfico
train.rename(rename_dict, axis = 1, inplace = True)
vali.rename(rename_dict, axis = 1, inplace = True)

## Configuración del experimento
s = setup(data = train,
          target = dep_var,
          test_data = vali,
          session_id = 123,
          index = False,
          numeric_features = num_vars,
          categorical_features = cat_vars,
          remove_multicollinearity = True,
          fix_imbalance = False,
          feature_selection = True,
          #feature_selection = False,
          feature_selection_method = "sequential",
          n_features_to_select = 0.5,
          use_gpu = False, 
         # log_experiment = True
         )

# compare baseline models
best = compare_models(sort = "F1", include = ['lr'])

# Generate feature importance plot 
plot_model(best, plot = 'feature', save = True)
shutil.copyfile(".\\"+"Feature Importance.png",
                ".\\"+temp_path+"ryr_results\\baseline_replicate\\predicted_probabilities\\features_{}_years_base_{}_{}.png".format(tgt_year, base_label, dep_var))
os.remove(".\\"+"Feature Importance.png")
# Out:
# Training horizon: 1, Initial state: 4, Outcome: fuera_metas.
# <style type="text/css">
# #T_4de12_row10_col1, #T_4de12_row16_col1, #T_4de12_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4de12_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4de12_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4de12_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4de12_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4de12_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4de12_row1_col1" class="data row1 col1" >fuera_metas</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4de12_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4de12_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4de12_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4de12_row3_col1" class="data row3 col1" >(7926, 27)</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4de12_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4de12_row4_col1" class="data row4 col1" >(7926, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4de12_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4de12_row5_col1" class="data row5 col1" >(5548, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4de12_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4de12_row6_col1" class="data row6 col1" >(2378, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4de12_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_4de12_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4de12_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_4de12_row8_col1" class="data row8 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4de12_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_4de12_row9_col1" class="data row9 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4de12_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_4de12_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4de12_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_4de12_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4de12_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_4de12_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4de12_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_4de12_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4de12_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_4de12_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4de12_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_4de12_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4de12_row16_col0" class="data row16 col0" >Remove multicollinearity</td>
#       <td id="T_4de12_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4de12_row17_col0" class="data row17 col0" >Multicollinearity threshold</td>
#       <td id="T_4de12_row17_col1" class="data row17 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4de12_row18_col0" class="data row18 col0" >Feature selection</td>
#       <td id="T_4de12_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4de12_row19_col0" class="data row19 col0" >Feature selection method</td>
#       <td id="T_4de12_row19_col1" class="data row19 col1" >sequential</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4de12_row20_col0" class="data row20 col0" >Feature selection estimator</td>
#       <td id="T_4de12_row20_col1" class="data row20 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4de12_row21_col0" class="data row21 col0" >Number of features selected</td>
#       <td id="T_4de12_row21_col1" class="data row21 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_4de12_row22_col0" class="data row22 col0" >Fold Generator</td>
#       <td id="T_4de12_row22_col1" class="data row22 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_4de12_row23_col0" class="data row23 col0" >Fold Number</td>
#       <td id="T_4de12_row23_col1" class="data row23 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_4de12_row24_col0" class="data row24 col0" >CPU Jobs</td>
#       <td id="T_4de12_row24_col1" class="data row24 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_4de12_row25_col0" class="data row25 col0" >Use GPU</td>
#       <td id="T_4de12_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_4de12_row26_col0" class="data row26 col0" >Log Experiment</td>
#       <td id="T_4de12_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_4de12_row27_col0" class="data row27 col0" >Experiment Name</td>
#       <td id="T_4de12_row27_col1" class="data row27 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4de12_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_4de12_row28_col0" class="data row28 col0" >USI</td>
#       <td id="T_4de12_row28_col1" class="data row28 col1" >1b23</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5d110_ th {
#   text-align: left;
# }
# #T_5d110_row0_col0 {
#   text-align: left;
# }
# #T_5d110_row0_col1, #T_5d110_row0_col2, #T_5d110_row0_col3, #T_5d110_row0_col4, #T_5d110_row0_col5, #T_5d110_row0_col6, #T_5d110_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5d110_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5d110_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d110_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_5d110_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_5d110_row0_col1" class="data row0 col1" >0.7358</td>
#       <td id="T_5d110_row0_col2" class="data row0 col2" >0.5490</td>
#       <td id="T_5d110_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_5d110_row0_col4" class="data row0 col4" >0.7358</td>
#       <td id="T_5d110_row0_col5" class="data row0 col5" >0.8478</td>
#       <td id="T_5d110_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_5d110_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_5d110_row0_col8" class="data row0 col8" >7.6590</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/9 [00:00<?, ?it/s]

# %% [markdown]
# ### Confusion matrix of two models

# %%
## Load the probabilities matrices
ordered_results = pd.read_csv(temp_path+"ryr_results\\baseline_replicate\\predicted_probabilities\\{}.csv".format("stats_res"), 
                        sep = ';')



confusion_entries = ordered_results.loc[(ordered_results['max_kappa'] == 1), 
                    ["tgt_year", "base_label", "dep_var", "sample", "Model", "tp", "tn", "fp", "fn"]]

# Compute rates
confusion_entries['TPR'] = confusion_entries['tp']/(confusion_entries['tp']+confusion_entries['fn'])
confusion_entries['FNR'] = 1-confusion_entries['TPR']
confusion_entries['FPR'] = confusion_entries['fp']/(confusion_entries['fp']+confusion_entries['tn'])
confusion_entries['TNR'] = 1-confusion_entries['FPR']


# Change the variables' labels
confusion_entries["tgt_year"].replace(to_replace = [1, 2], 
                                      value = ["1-year", 
                                               "2-year"], 
                                        inplace = True)

confusion_entries["base_label"].replace(to_replace = [1, 2, 3, 4], 
                                      value = ["1 On-goals", 
                                                 "2 Out-goals", 
                                                 "3 Not-complications", 
                                                 "4 Yes-complications"], 
                                        inplace = True)

confusion_entries["dep_var"].replace(to_replace = ["fuera_metas", "comorbilidades"], 
                                      value = ["Out-goals", "Yes-complications"], 
                                        inplace = True)

confusion_entries["sample"].replace(to_replace = ["training", "validation"], 
                                      value = ["Training", "Validation"],
                                        inplace = True)

confusion_entries.replace(to_replace = ['LogisticRegression', 'AdaBoostClassifier', 'GradientBoostingClassifier', 'LGBMClassifier'], 
                          value = ["LR", "AdaBoost", "GBC", "LGBoost"], 
                          inplace = True)

# Renaming different columns
rename_dict = {"tgt_year" : "Horizon", 
               "base_label" : "Initial condition",
               "dep_var" : "Prediction", 
               "accuracy" : "Accuracy",
               "f1" : "F1-score", 
               "auc" : "AUC", 
               "tp" : "True Pos.", 
               "tn" : "True Neg.", 
               "fp" : "False Pos.", 
               "fn" : "False Neg."}

## Generate results for naive model
subsample = pd.pivot(confusion_entries.rename(rename_dict, axis = 1), 
                     index = ['Horizon', 'Initial condition',  'Prediction', "Model"], 
                     columns = "sample", 
                     values = ["True Pos.", 
                              "True Neg.", 
                              "False Pos.", 
                              "False Neg."]).reset_index()

# Rows sorting
subsample = pd.concat([subsample[(subsample['Prediction'] == "Out-goals") & (subsample['Horizon'] == "1-year")], 
           subsample[(subsample['Prediction'] == "Yes-complications") & (subsample['Horizon'] == "1-year")],
           subsample[(subsample['Prediction'] == "Out-goals") & (subsample['Horizon'] == "2-year")], 
           subsample[(subsample['Prediction'] == "Yes-complications") & (subsample['Horizon'] == "2-year")]])

# Final cleaning
subsample['Initial condition'] = subsample['Initial condition'].str.replace('\d+', '')
cols_order = [('Horizon',''),
              ('Initial condition',''),
              ('Prediction',''),
              ('Model','')] + [(y, x) for x in ["Training", 
                                                "Validation"] for y in ["True Pos.", 
                                                                        "True Neg.", 
                                                                        "False Pos.", 
                                                                        "False Neg."]]
subsample = subsample.loc[:, cols_order].round(4)
subsample.to_csv("ryr_results\\baseline_replicate\\predicted_probabilities\\confusion_matrices.csv", 
                 sep = ";", index = False)


print("Confusion matrix under optimal cutoff:")
subsample
# Out:
# Confusion matrix under optimal cutoff:
#        Horizon   Initial condition         Prediction     Model True Pos.  \
# sample                                                           Training
# 0       1-year            On-goals          Out-goals        NN       386
# 2       1-year           Out-goals          Out-goals        LR      1430
# 4       1-year   Not-complications          Out-goals        NN       554
# 5       1-year   Yes-complications          Out-goals        LR      2231
# 1       1-year            On-goals  Yes-complications  AdaBoost      1941
# 3       1-year           Out-goals  Yes-complications       GBC      1655
# 6       2-year            On-goals          Out-goals        NN       240
# 8       2-year           Out-goals          Out-goals   LGBoost       849
# 10      2-year   Not-complications          Out-goals        NN       375
# 11      2-year   Yes-complications          Out-goals        LR       841
# 7       2-year            On-goals  Yes-complications        LR      1764
# 9       2-year           Out-goals  Yes-complications        LR       868
#
#        True Neg. False Pos. False Neg.  True Pos.  True Neg. False Pos.  \
# sample  Training   Training   Training Validation Validation Validation
# 0           2521        162        191        130        680        470
# 2            298        495        633        429        211        130
# 4           4294        493        552        109       1774        278
# 5            796        670       1851       1163        254        375
# 1            409        727        183        840        136        351
# 3            445        508        248        760        102        307
# 6           1435        223        249         99        492        220
# 8            332        302        405        382        101        171
# 10          1662         90         65         96        438        313
# 11           412        338        679        596         45        277
# 7             32        176        175        819          4         85
# 9            104         71        845        716          5         69
#
#        False Neg.
# sample Validation
# 0             118
# 2             455
# 4             365
# 5             586
# 1              71
# 3              56
# 6             110
# 8             156
# 10             93
# 11             55
# 7              13
# 9              20

# %%
## Generate results for naive model
subsample = pd.pivot(confusion_entries.rename(rename_dict, axis = 1), 
                     index = ['Horizon', 'Initial condition',  'Prediction', "Model"], 
                     columns = "sample", 
                     values = ["TPR", 
                              "FPR", 
                              "TNR", 
                              "FNR"]).reset_index()

# Rows sorting
subsample = pd.concat([subsample[(subsample['Prediction'] == "Out-goals") & (subsample['Horizon'] == "1-year")], 
           subsample[(subsample['Prediction'] == "Yes-complications") & (subsample['Horizon'] == "1-year")],
           subsample[(subsample['Prediction'] == "Out-goals") & (subsample['Horizon'] == "2-year")], 
           subsample[(subsample['Prediction'] == "Yes-complications") & (subsample['Horizon'] == "2-year")]])

# Final cleaning
subsample['Initial condition'] = subsample['Initial condition'].str.replace('\d+', '')
cols_order = [('Horizon',''),
              ('Initial condition',''),
              ('Prediction',''),
              ('Model','')] + [(y, x) for x in ["Training", 
                                                "Validation"] for y in ["TPR", 
                                                                          "FPR", 
                                                                          "TNR", 
                                                                          "FNR"]]
subsample = subsample.loc[:, cols_order].round(4)
subsample.to_csv("ryr_results\\baseline_replicate\\predicted_probabilities\\confusion_matrices_rates.csv", 
                 sep = ";", index = False)


print("Confusion matrix under optimal cutoff:")
subsample
# Out:
# Confusion matrix under optimal cutoff:
#        Horizon   Initial condition         Prediction     Model      TPR  \
# sample                                                          Training
# 0       1-year            On-goals          Out-goals        NN   0.6690
# 2       1-year           Out-goals          Out-goals        LR   0.6932
# 4       1-year   Not-complications          Out-goals        NN   0.5009
# 5       1-year   Yes-complications          Out-goals        LR   0.5465
# 1       1-year            On-goals  Yes-complications  AdaBoost   0.9138
# 3       1-year           Out-goals  Yes-complications       GBC   0.8697
# 6       2-year            On-goals          Out-goals        NN   0.4908
# 8       2-year           Out-goals          Out-goals   LGBoost   0.6770
# 10      2-year   Not-complications          Out-goals        NN   0.8523
# 11      2-year   Yes-complications          Out-goals        LR   0.5533
# 7       2-year            On-goals  Yes-complications        LR   0.9097
# 9       2-year           Out-goals  Yes-complications        LR   0.5067
#
#             FPR      TNR      FNR        TPR        FPR        TNR        FNR
# sample Training Training Training Validation Validation Validation Validation
# 0        0.0604   0.9396   0.3310     0.5242     0.4087     0.5913     0.4758
# 2        0.6242   0.3758   0.3068     0.4853     0.3812     0.6188     0.5147
# 4        0.1030   0.8970   0.4991     0.2300     0.1355     0.8645     0.7700
# 5        0.4570   0.5430   0.4535     0.6650     0.5962     0.4038     0.3350
# 1        0.6400   0.3600   0.0862     0.9221     0.7207     0.2793     0.0779
# 3        0.5331   0.4669   0.1303     0.9314     0.7506     0.2494     0.0686
# 6        0.1345   0.8655   0.5092     0.4737     0.3090     0.6910     0.5263
# 8        0.4763   0.5237   0.3230     0.7100     0.6287     0.3713     0.2900
# 10       0.0514   0.9486   0.1477     0.5079     0.4168     0.5832     0.4921
# 11       0.4507   0.5493   0.4467     0.9155     0.8602     0.1398     0.0845
# 7        0.8462   0.1538   0.0903     0.9844     0.9551     0.0449     0.0156
# 9        0.4057   0.5943   0.4933     0.9728     0.9324     0.0676     0.0272

# %% [markdown]
# ### Barplot of F1-scores

# %%
## Load the long panel of results
#stats_long = pd.read_csv(temp_path + 'original_submission_res_long.csv', 
#                         sep = ';')

stats_long = pd.read_csv(temp_path + "kappa_opt_long_res.csv", sep = ';')
stats_long = stats_long[stats_long['max_kappa'] == 1]

# Correct the base labels and the variables names
stats_long["base_label"].replace(to_replace = ["1 On-target", 
                                                 "2 Out-target", 
                                                 "3 Not-complications", 
                                                 "4 Yes-complications"], 
                                      value = ["On-target", 
                                                 "Out-target", 
                                                 "Not-complications", 
                                                 "Yes-complications"], 
                                        inplace = True)

stats_long.rename(columns = {"tgt_year" : "Horizon", 
                             "sample" : "Sample", 
                             "f1" : "F1 Score"}, 
                  inplace = True)

stats_long["Init. Cond.-Pred."] = stats_long['base_label']+"-"+stats_long['dep_var']

## Generate the barplot depending on the horizon 

fig = px.bar(stats_long, 
       x = "Init. Cond.-Pred.", y = "F1 Score",
       facet_row = 'Horizon', facet_col = "Sample", color = 'Init. Cond.-Pred.')

fig.update_layout(legend = dict(orientation = 'h', 
                               xanchor = 'left', 
                               x = -0.1))
fig.update_xaxes(visible=False)
pio.write_image(fig,
                temp_path+"ryr_results\\baseline_replicate\\predicted_probabilities\\"+"f1_score_per_model.jpg", 
                format="jpeg", 
                scale=1, width=1000, height=800)
